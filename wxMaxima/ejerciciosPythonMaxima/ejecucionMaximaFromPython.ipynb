# %% [markdown]
# ## SageMath
#
# sudo apt update
# sudot apt install sagemath

# %%
from sageall import maxima

print(maxima('integrate(sin(x), x)'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sageall import maxima
#       3 print(maxima('integrate(sin(x), x)'))
#
# ModuleNotFoundError: No module named 'sageall'

# %% [markdown]
# ## Con maxima_interface

# %%
# %pip install maxima_interface
# Out:
# Requirement already satisfied: maxima_interface in /home/miguel/miniconda3/envs/CondaCodingQiskitEnvironment/lib/python3.13/site-packages (0.1.1)
# Requirement already satisfied: psutil==5.9.* in /home/miguel/miniconda3/envs/CondaCodingQiskitEnvironment/lib/python3.13/site-packages (from maxima_interface) (5.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from maxima_interface import MaximaInterface

mi = MaximaInterface()
mi.raw_command("a: sqrt(9);")
result = mi.raw_command("a;")

print(result)

mi.close()
# Out:
# 3

# %% [markdown]
# ## Con sympy

# %%
import sympy

x = sympy.Symbol('x')

# Define una función
f = x**2 + 2*x + 1

# Calcula la derivada
df = sympy.diff(f, x)

# Imprime el resultado
print(df)
# Out:
# 2*x + 2

# %% [markdown]
# ## Con OS_system

# %%
import os

# %%
# Ejemplo: Calcular la derivada de x^2 en Maxima
comando = "maxima --batch-string=\"diff(x^2, x);\""
# Ejecutar el comando y capturar el código de salida
codigo_salida = os.system(comando)
if codigo_salida == 0:
    print("Comando ejecutado correctamente.")
else:
    print(f"Error al ejecutar el comando. Código de salida: {codigo_salida}")
# Out:
# Maxima 5.46.0 https://maxima.sourceforge.io
# using Lisp GNU Common Lisp (GCL) GCL 2.6.14 git tag Version_2_6_15pre7
# Distributed under the GNU Public License. See the file COPYING.
# Dedicated to the memory of William Schelter.
# The function bug_report() provides bug reporting information.
# (%i1) diff(x^2,x)
# (%o1)                                 2 x
# Comando ejecutado correctamente.

# %% [markdown]
# ## Como subproceso
#
# Maxima se puede invocar como proceso desde Python con el módulo estándar subprocess.

# %%
import subprocess

# %%
def run_maxima(code):
    process = subprocess.Popen(
        ["maxima", "--very-quiet"],
        stdin=subprocess.PIPE,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True
    )
    out, err = process.communicate(code + ";\n")
    return out

print(run_maxima("sqrt(9)"))
# Out:
#                                        3

# %% [markdown]
# ## pymaxima
# Un wrapper ligero para ejecutar Maxima desde Python.

# %%
# %pip install pymaxima
# Out:
# ERROR: Could not find a version that satisfies the requirement pymaxima (from versions: none)
# ERROR: No matching distribution found for pymaxima
# Note: you may need to restart the kernel to use updated packages.
